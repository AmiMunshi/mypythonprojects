# %% [markdown]
# ##Generating Square Wave

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal
f=10
t=np.linspace(0,1,500)
amp=5
x= amp*signal.square(2*np.pi*f*t)
plt.plot(t,x)
plt.xlabel('time (s)')
plt.ylabel('amplitude(V)')
plt.show()
